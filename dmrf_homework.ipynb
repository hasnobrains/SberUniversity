# %% [markdown]
# ## Задание
# * Собрать информацию о всех строящихся объектах на сайте "наш.дом.рф"
# * Cохранить ее в pandas dataframe
# * Cохранить pandas dataframe в excel
# * Cохранить pandas dataframe в pickle
# * Cохранить pandas dataframe в БД
#
# ## Задание *
# * Написать скрипт, который скачивает фотографии всех строящихся объектов с сайта "наш.дом.рф"

# %%
import requests

# %% [markdown]
# ###  Список айдишников новостроек

# %%
offset = 0       # отступ в запросе
limit = 1000     # литмит на выдачу
objects_ids_total = [] # список айдишников всех новостроек

# %%
while True:
    url = f'https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/api/kn/object?offset={offset}&limit={limit}&sortField=devId.devShortCleanNm&sortType=asc&objStatus=0'
    res = requests.get(url)
    data = res.json()['data']
    data_length = len(data['list'])
    if data_length > 0:
        objects_list = data['list']
        objects_ids = [x.get('objId') for x in objects_list]
        objects_ids_total += objects_ids
        print(f'objects total = {len(objects_ids_total)}')
        offset += limit
    else:
        break # если вернулся пустой список
# Out:
# objects total = 1000
# objects total = 2000
# objects total = 3000
# objects total = 4000
# objects total = 5000
# objects total = 6000
# objects total = 7000
# objects total = 8000
# objects total = 9000
# objects total = 10000
# objects total = 10202

# %%
len(objects_ids_total)
# Out:
# 10202

# %% [markdown]
# Итого: 10202 новостройки

# %% [markdown]
# ### Данные по каждому объекту

# %%
table = [] # результирующая таблица

# %%
for id in objects_ids_total:
    cell = {}
    print(f'Collecting object {id} info ...')
    url = f'https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/api/object/{id}'
    res = requests.get(url)
    data = res.json()['data']
    try:
        cell['id'] = data.get('id')
        cell['region'] = data.get('region')
        cell['address'] = data.get('address')
        cell['name'] = data.get('nameObj')
        cell['floors'] = data.get('floorMin')
        cell['flats'] = data.get('objElemLivingCnt')
        cell['parking'] = data.get('objElemParkingCnt')
        cell['ready_date'] = data.get('objReady100PercDt')
        cell['material'] = data.get('wallMaterialShortDesc')
        cell['class'] = data.get('objLkClassDesc')
        cell['url'] = url
    except:
        break
        
    table.append(cell)
# Out:
# Collecting object 25002 info ...
# Collecting object 13399 info ...
# Collecting object 13398 info ...
# Collecting object 13383 info ...
# Collecting object 13397 info ...
# Collecting object 13391 info ...
# Collecting object 23682 info ...
# Collecting object 36321 info ...
# Collecting object 37071 info ...
# Collecting object 36912 info ...
# Collecting object 23494 info ...
# Collecting object 25133 info ...
# Collecting object 27476 info ...
# Collecting object 27475 info ...
# Collecting object 26194 info ...
# Collecting object 23010 info ...
# Collecting object 27474 info ...
# Collecting object 27473 info ...
# Collecting object 10891 info ...
# Collecting object 39174 info ...
# Collecting object 39176 info ...
# Collecting object 39175 info ...
# Collecting object 41421 info ...
# Collecting object 33928 info ...
# Collecting object 41420 info ...
# Collecting object 30292 info ...
# Collecting object 18363 info ...
# Collecting object 18709 info ...
# Collecting object 18708 info ...
# Collecting object 21535 info ...
# Collecting object 21534 info ...
# Collecting object 9335 info ...
# Collecting object 21537 info ...
# Collecting object 9336 info ...
# Collecting object 21536 info ...
# Collecting object 39319 info ...
# Collecting object 30243 info ...
# Collecting object 39741 info ...
# Collecting object 41625 info ...
# Collecting object 41624 info ...
# Collecting object 26503 info ...
# Collecting object 42192 info ...
# Collecting object 38871 info ...
# Collecting object 27542 info ...
# Collecting object 26903 info ...
# Collecting object 20524 info ...
# Collecting object 29184 info ...
# Collecting object 27779 info ...
# Collecting object 24093 info ...
# Collecting object 35830 info ...
# Collecting object 32811 info ...
# Collecting object 32819 info ...
# Collecting object 32836 info ...
# Collecting object 32829 info ...
# Collecting object 32815 info ...
# Collecting object 27802 info ...
# Collecting object 32827 info ...
# Collecting object 32843 info ...
# Collecting object 32820 info ...
# Collecting object 32838 info ...
# Collecting object 27807 info ...
# Collecting object 32825 info ...
# Collecting object 32818 info ...
# Collecting object 32837 info ...
# Collecting object 27806 info ...
# Collecting object 27803 info ...
# Collecting object 32839 info ...
# Collecting object 32840 info ...
# Collecting object 32841 info ...
# Collecting object 32814 info ...
# Collecting object 32830 info ...
# Collecting object 32835 info ...
# Collecting object 32831 info ...
# Collecting object 32826 info ...
# Collecting object 32813 info ...
# Collecting object 32833 info ...
# Collecting object 32817 info ...
# Collecting object 27801 info ...
# Collecting object 32824 info ...
# Collecting object 27808 info ...
# Collecting object 32823 info ...
# Collecting object 32842 info ...
# Collecting object 32816 info ...
# Collecting object 32832 info ...
# Collecting object 32834 info ...
# Collecting object 27798 info ...
# Collecting object 32828 info ...
# Collecting object 32812 info ...
# Collecting object 22376 info ...
# Collecting object 22378 info ...
# Collecting object 22379 info ...
# Collecting object 22375 info ...
# Collecting object 22377 info ...
# Collecting object 21719 info ...
# Collecting object 21720 info ...
# Collecting object 4402 info ...
# Collecting object 33899 info ...
# Collecting object 17712 info ...
# Collecting object 17707 info ...
# Collecting object 33745 info ...
# Collecting object 40061 info ...
# Collecting object 39130 info ...
# Collecting object 15886 info ...
# Collecting object 15888 info ...
# Collecting object 15889 info ...
# Collecting object 15885 info ...
# Collecting object 15891 info ...
# Collecting object 15890 info ...
# Collecting object 23401 info ...
# Collecting object 37264 info ...
# Collecting object 24820 info ...
# Collecting object 24823 info ...
# Collecting object 41618 info ...
# Collecting object 41616 info ...
# Collecting object 24822 info ...
# Collecting object 41612 info ...
# Collecting object 41620 info ...
# Collecting object 24819 info ...
# Collecting object 24818 info ...
# Collecting object 24817 info ...
# Collecting object 3429 info ...
# Collecting object 41613 info ...
# Collecting object 41615 info ...
# Collecting object 41617 info ...
# Collecting object 41621 info ...
# Collecting object 41614 info ...
# Collecting object 41619 info ...
# Collecting object 31879 info ...
# Collecting object 22946 info ...
# Collecting object 2968 info ...
# Collecting object 2972 info ...
# Collecting object 2969 info ...
# Collecting object 2967 info ...
# Collecting object 18136 info ...
# Collecting object 18135 info ...
# Collecting object 42366 info ...
# Collecting object 42365 info ...
# Collecting object 32082 info ...
# Collecting object 32080 info ...
# Collecting object 37465 info ...
# Collecting object 33525 info ...
# Collecting object 3148 info ...
# Collecting object 33203 info ...
# Collecting object 33134 info ...
# Collecting object 33194 info ...
# Collecting object 33223 info ...
# Collecting object 33102 info ...
# Collecting object 33224 info ...
# Collecting object 33176 info ...
# Collecting object 33103 info ...
# Collecting object 33161 info ...
# Collecting object 33217 info ...
# Collecting object 33112 info ...
# Collecting object 33105 info ...
# Collecting object 33136 info ...
# Collecting object 33137 info ...
# Collecting object 33151 info ...
# Collecting object 33186 info ...
# Collecting object 33106 info ...
# Collecting object 33147 info ...
# Collecting object 33206 info ...
# Collecting object 33155 info ...
# Collecting object 33139 info ...
# Collecting object 33230 info ...
# Collecting object 33108 info ...
# Collecting object 33160 info ...
# Collecting object 33158 info ...
# Collecting object 33175 info ...
# Collecting object 33214 info ...
# Collecting object 33168 info ...
# Collecting object 33235 info ...
# Collecting object 33123 info ...
# Collecting object 33150 info ...
# Collecting object 33216 info ...
# Collecting object 33195 info ...
# Collecting object 33236 info ...
# Collecting object 33110 info ...
# Collecting object 33171 info ...
# Collecting object 33164 info ...
# Collecting object 33138 info ...
# Collecting object 33215 info ...
# Collecting object 33121 info ...
# Collecting object 33130 info ...
# Collecting object 33167 info ...
# Collecting object 33226 info ...
# Collecting object 33142 info ...
# Collecting object 33140 info ...
# Collecting object 33182 info ...
# Collecting object 33152 info ...
# Collecting object 33234 info ...
# Collecting object 33183 info ...
# Collecting object 33157 info ...
# Collecting object 33188 info ...
# Collecting object 33229 info ...
# Collecting object 33172 info ...
# Collecting object 33213 info ...
# Collecting object 33190 info ...
# Collecting object 33227 info ...
# Collecting object 33145 info ...
# Collecting object 33165 info ...
# Collecting object 33101 info ...
# Collecting object 33174 info ...
# Collecting object 33200 info ...
# Collecting object 33098 info ...
# Collecting object 33210 info ...
# Collecting object 33149 info ...
# Collecting object 33193 info ...
# Collecting object 33173 info ...
# Collecting object 33189 info ...
# Collecting object 33197 info ...
# Collecting object 33177 info ...
# Collecting object 33201 info ...
# Collecting object 33237 info ...
# Collecting object 33187 info ...
# Collecting object 33205 info ...
# Collecting object 33096 info ...
# Collecting object 33153 info ...
# Collecting object 33184 info ...
# Collecting object 33166 info ...
# Collecting object 33185 info ...
# Collecting object 33146 info ...
# Collecting object 33169 info ...
# Collecting object 33196 info ...
# Collecting object 33144 info ...
# Collecting object 33225 info ...
# Collecting object 33228 info ...
# Collecting object 33115 info ...
# Collecting object 33143 info ...
# Collecting object 33221 info ...
# Collecting object 33156 info ...
# Collecting object 33097 info ...
# Collecting object 33148 info ...
# Collecting object 33204 info ...
# Collecting object 33233 info ...
# Collecting object 33218 info ...
# Collecting object 33113 info ...
# Collecting object 33208 info ...
# Collecting object 33209 info ...
# Collecting object 33202 info ...
# Collecting object 33178 info ...
# Collecting object 33219 info ...
# Collecting object 33211 info ...
# Collecting object 33095 info ...
# Collecting object 33107 info ...
# Collecting object 33162 info ...
# Collecting object 33220 info ...
# Collecting object 33180 info ...
# Collecting object 33231 info ...
# Collecting object 33191 info ...
# Collecting object 33212 info ...
# Collecting object 33122 info ...
# Collecting object 33192 info ...
# Collecting object 33135 info ...
# Collecting object 33207 info ...
# Collecting object 33179 info ...
# Collecting object 33199 info ...
# Collecting object 33222 info ...
# Collecting object 33232 info ...
# Collecting object 33170 info ...
# Collecting object 33159 info ...
# Collecting object 33181 info ...
# Collecting object 33141 info ...
# Collecting object 33100 info ...
# Collecting object 33099 info ...
# Collecting object 33154 info ...
# Collecting object 33163 info ...
# Collecting object 33198 info ...
# Collecting object 16113 info ...
# Collecting object 25425 info ...
# Collecting object 43141 info ...
# Collecting object 43140 info ...
# Collecting object 34228 info ...
# Collecting object 32916 info ...
# Collecting object 4024 info ...
# Collecting object 4020 info ...
# Collecting object 4025 info ...
# Collecting object 4023 info ...
# Collecting object 4026 info ...
# Collecting object 4022 info ...
# Collecting object 4021 info ...
# Collecting object 35042 info ...
# Collecting object 26995 info ...
# Collecting object 26996 info ...
# Collecting object 41385 info ...
# Collecting object 37725 info ...
# Collecting object 41386 info ...
# Collecting object 37726 info ...
# Collecting object 37727 info ...
# Collecting object 33781 info ...
# Collecting object 33782 info ...
# Collecting object 33783 info ...
# Collecting object 33779 info ...
# Collecting object 33780 info ...
# Collecting object 31821 info ...
# Collecting object 22776 info ...
# Collecting object 28044 info ...
# Collecting object 27208 info ...
# Collecting object 27789 info ...
# Collecting object 28214 info ...
# Collecting object 28047 info ...
# Collecting object 27209 info ...
# Collecting object 27597 info ...
# Collecting object 28215 info ...
# Collecting object 28049 info ...
# Collecting object 27783 info ...
# Collecting object 27787 info ...
# Collecting object 27206 info ...
# Collecting object 28210 info ...
# Collecting object 28043 info ...
# Collecting object 27204 info ...
# Collecting object 28048 info ...
# Collecting object 28212 info ...
# Collecting object 28046 info ...
# Collecting object 28211 info ...
# Collecting object 27786 info ...
# Collecting object 28042 info ...
# Collecting object 27205 info ...
# Collecting object 27207 info ...
# Collecting object 28216 info ...
# Collecting object 28213 info ...
# Collecting object 27596 info ...
# Collecting object 28045 info ...
# Collecting object 27788 info ...
# Collecting object 28208 info ...
# Collecting object 28209 info ...
# Collecting object 27782 info ...
# Collecting object 27790 info ...
# Collecting object 27203 info ...
# Collecting object 27784 info ...
# Collecting object 39995 info ...
# Collecting object 29554 info ...
# Collecting object 23444 info ...
# Collecting object 42203 info ...
# Collecting object 28255 info ...
# Collecting object 28254 info ...
# Collecting object 28256 info ...
# Collecting object 42499 info ...
# Collecting object 44006 info ...
# Collecting object 42485 info ...
# Collecting object 42129 info ...
# Collecting object 27630 info ...
# Collecting object 25763 info ...
# Collecting object 27628 info ...
# Collecting object 27631 info ...
# Collecting object 27629 info ...
# Collecting object 27633 info ...
# Collecting object 27632 info ...
# Collecting object 39675 info ...
# Collecting object 43214 info ...
# Collecting object 34185 info ...
# Collecting object 37425 info ...
# Collecting object 27529 info ...
# Collecting object 42935 info ...
# Collecting object 36016 info ...
# Collecting object 37518 info ...
# Collecting object 37520 info ...
# Collecting object 37519 info ...
# Collecting object 8159 info ...
# Collecting object 23229 info ...
# Collecting object 26213 info ...
# Collecting object 26212 info ...
# Collecting object 31397 info ...
# Collecting object 31395 info ...
# Collecting object 31400 info ...
# Collecting object 31399 info ...
# Collecting object 31398 info ...
# Collecting object 31394 info ...
# Collecting object 31393 info ...
# Collecting object 31396 info ...
# Collecting object 22564 info ...
# Collecting object 23969 info ...
# Collecting object 21294 info ...
# Collecting object 21295 info ...
# Collecting object 21296 info ...
# Collecting object 21293 info ...
# Collecting object 28185 info ...
# Collecting object 27484 info ...
# Collecting object 30481 info ...
# Collecting object 30516 info ...
# Collecting object 2928 info ...
# Collecting object 41916 info ...
# Collecting object 43660 info ...
# Collecting object 43659 info ...
# Collecting object 43815 info ...
# Collecting object 8930 info ...
# Collecting object 8922 info ...
# Collecting object 8938 info ...
# Collecting object 8932 info ...
# Collecting object 8919 info ...
# Collecting object 8936 info ...
# Collecting object 8917 info ...
# Collecting object 8921 info ...
# Collecting object 8920 info ...
# Collecting object 8937 info ...
# Collecting object 8927 info ...
# Collecting object 8915 info ...
# Collecting object 8916 info ...
# Collecting object 8926 info ...
# Collecting object 8918 info ...
# Collecting object 8934 info ...
# Collecting object 8928 info ...
# Collecting object 8929 info ...
# Collecting object 8924 info ...
# Collecting object 28799 info ...
# Collecting object 26472 info ...
# Collecting object 34734 info ...
# Collecting object 26181 info ...
# Collecting object 26180 info ...
# Collecting object 26182 info ...
# Collecting object 28444 info ...
# Collecting object 35468 info ...
# Collecting object 35467 info ...
# Collecting object 35466 info ...
# Collecting object 25055 info ...
# Collecting object 25066 info ...
# Collecting object 25056 info ...
# Collecting object 25065 info ...
# Collecting object 31297 info ...
# Collecting object 20844 info ...
# Collecting object 38826 info ...
# Collecting object 28167 info ...
# Collecting object 28165 info ...
# Collecting object 28164 info ...
# Collecting object 28162 info ...
# Collecting object 28166 info ...
# Collecting object 28163 info ...
# Collecting object 30242 info ...
# Collecting object 40419 info ...
# Collecting object 13410 info ...
# Collecting object 6794 info ...
# Collecting object 7514 info ...
# Collecting object 32540 info ...
# Collecting object 32389 info ...
# Collecting object 32391 info ...
# Collecting object 32394 info ...
# Collecting object 32396 info ...
# Collecting object 32404 info ...
# Collecting object 32373 info ...
# Collecting object 32534 info ...
# Collecting object 32538 info ...
# Collecting object 32527 info ...
# Collecting object 32528 info ...
# Collecting object 32537 info ...
# Collecting object 32392 info ...
# Collecting object 32395 info ...
# Collecting object 32367 info ...
# Collecting object 32533 info ...
# Collecting object 32400 info ...
# Collecting object 32398 info ...
# Collecting object 32405 info ...
# Collecting object 32541 info ...
# Collecting object 32543 info ...
# Collecting object 32402 info ...
# Collecting object 32381 info ...
# Collecting object 32380 info ...
# Collecting object 32399 info ...
# Collecting object 32382 info ...
# Collecting object 32368 info ...
# Collecting object 32372 info ...
# Collecting object 32536 info ...
# Collecting object 32535 info ...
# Collecting object 32371 info ...
# Collecting object 32393 info ...
# Collecting object 32401 info ...
# Collecting object 32529 info ...
# Collecting object 32531 info ...
# Collecting object 32545 info ...
# Collecting object 32403 info ...
# Collecting object 32532 info ...
# Collecting object 32530 info ...
# Collecting object 32544 info ...
# Collecting object 32407 info ...
# Collecting object 32406 info ...
# Collecting object 32383 info ...
# Collecting object 32542 info ...
# Collecting object 32397 info ...
# Collecting object 32379 info ...
# Collecting object 32370 info ...
# Collecting object 32390 info ...
# Collecting object 32388 info ...
# Collecting object 32369 info ...
# Collecting object 32539 info ...
# Collecting object 36377 info ...
# Collecting object 3639 info ...
# Collecting object 3643 info ...
# Collecting object 3644 info ...
# Collecting object 3641 info ...
# Collecting object 3636 info ...
# Collecting object 3645 info ...
# Collecting object 3637 info ...
# Collecting object 3642 info ...
# Collecting object 3635 info ...
# Collecting object 3638 info ...
# Collecting object 3632 info ...
# Collecting object 3640 info ...
# Collecting object 3633 info ...
# Collecting object 3630 info ...
# Collecting object 27677 info ...
# Collecting object 44442 info ...
# Collecting object 44441 info ...
# Collecting object 44445 info ...
# Collecting object 44443 info ...
# Collecting object 44444 info ...
# Collecting object 44439 info ...
# Collecting object 44440 info ...
# Collecting object 31230 info ...
# Collecting object 31231 info ...
# Collecting object 37712 info ...
# Collecting object 42058 info ...
# Collecting object 34533 info ...
# Collecting object 36761 info ...
# Collecting object 38604 info ...
# Collecting object 42259 info ...
# Collecting object 31176 info ...
# Collecting object 31177 info ...
# Collecting object 38441 info ...
# Collecting object 35709 info ...
# Collecting object 37690 info ...
# Collecting object 35971 info ...
# Collecting object 35251 info ...
# Collecting object 43893 info ...
# Collecting object 43177 info ...
# Collecting object 36190 info ...
# Collecting object 35970 info ...
# Collecting object 37034 info ...
# Collecting object 43099 info ...
# Collecting object 36898 info ...
# Collecting object 36897 info ...
# Collecting object 37840 info ...
# Collecting object 38194 info ...
# Collecting object 34884 info ...
# Collecting object 41083 info ...
# Collecting object 35694 info ...
# Collecting object 42280 info ...
# Collecting object 35410 info ...
# Collecting object 39316 info ...
# Collecting object 34497 info ...
# Collecting object 40819 info ...
# Collecting object 43853 info ...
# Collecting object 37183 info ...
# Collecting object 42843 info ...
# Collecting object 36438 info ...
# Collecting object 38969 info ...
# Collecting object 31178 info ...
# Collecting object 38553 info ...
# Collecting object 38990 info ...
# Collecting object 41358 info ...
# Collecting object 41356 info ...
# Collecting object 41359 info ...
# Collecting object 41354 info ...
# Collecting object 41355 info ...
# Collecting object 41357 info ...
# Collecting object 39790 info ...
# Collecting object 42385 info ...
# Collecting object 31360 info ...
# Collecting object 31361 info ...
# Collecting object 44417 info ...
# Collecting object 31999 info ...
# Collecting object 31998 info ...
# Collecting object 24316 info ...
# Collecting object 24319 info ...
# Collecting object 24317 info ...
# Collecting object 24318 info ...
# Collecting object 37931 info ...
# Collecting object 3373 info ...
# Collecting object 22496 info ...
# Collecting object 23273 info ...
# Collecting object 23276 info ...
# Collecting object 23272 info ...
# Collecting object 23274 info ...
# Collecting object 23278 info ...
# Collecting object 23279 info ...
# Collecting object 23277 info ...
# Collecting object 23275 info ...
# Collecting object 20702 info ...
# Collecting object 20705 info ...
# Collecting object 20701 info ...
# Collecting object 20706 info ...
# Collecting object 20703 info ...
# Collecting object 23238 info ...
# Collecting object 23242 info ...
# Collecting object 23239 info ...
# Collecting object 23237 info ...
# Collecting object 23241 info ...
# Collecting object 23240 info ...
# Collecting object 3986 info ...
# Collecting object 16824 info ...
# Collecting object 26134 info ...
# Collecting object 35599 info ...
# Collecting object 26133 info ...
# Collecting object 27149 info ...
# Collecting object 44376 info ...
# Collecting object 27148 info ...
# Collecting object 25607 info ...
# Collecting object 25609 info ...
# Collecting object 25608 info ...
# Collecting object 25606 info ...
# Collecting object 11448 info ...
# Collecting object 11447 info ...
# Collecting object 42434 info ...
# Collecting object 36281 info ...
# Collecting object 11446 info ...
# Collecting object 39612 info ...
# Collecting object 28975 info ...
# Collecting object 8148 info ...
# Collecting object 29148 info ...
# Collecting object 41872 info ...
# Collecting object 24539 info ...
# Collecting object 24540 info ...
# Collecting object 44385 info ...
# Collecting object 44382 info ...
# Collecting object 44381 info ...
# Collecting object 44383 info ...
# Collecting object 44384 info ...
# Collecting object 30973 info ...
# Collecting object 43506 info ...
# Collecting object 13983 info ...
# Collecting object 13981 info ...
# Collecting object 13982 info ...
# Collecting object 13986 info ...
# Collecting object 43711 info ...
# Collecting object 16958 info ...
# Collecting object 39287 info ...
# Collecting object 37228 info ...
# Collecting object 13723 info ...
# Collecting object 38113 info ...
# Collecting object 10535 info ...
# Collecting object 10533 info ...
# Collecting object 10534 info ...
# Collecting object 31338 info ...
# Collecting object 31339 info ...
# Collecting object 30176 info ...
# Collecting object 34891 info ...
# Collecting object 4060 info ...
# Collecting object 42501 info ...
# Collecting object 32188 info ...
# Collecting object 42500 info ...
# Collecting object 44321 info ...
# Collecting object 24590 info ...
# Collecting object 36029 info ...
# Collecting object 14123 info ...
# Collecting object 36027 info ...
# Collecting object 36025 info ...
# Collecting object 38321 info ...
# Collecting object 38320 info ...
# Collecting object 39334 info ...
# Collecting object 36024 info ...
# Collecting object 38326 info ...
# Collecting object 36026 info ...
# Collecting object 38325 info ...
# Collecting object 38323 info ...
# Collecting object 39335 info ...
# Collecting object 38324 info ...
# Collecting object 36028 info ...
# Collecting object 39336 info ...
# Collecting object 38322 info ...
# Collecting object 42790 info ...
# Collecting object 42792 info ...
# Collecting object 42791 info ...
# Collecting object 41047 info ...
# Collecting object 28087 info ...
# Collecting object 37847 info ...
# Collecting object 43190 info ...
# Collecting object 38307 info ...
# Collecting object 38306 info ...
# Collecting object 26676 info ...
# Collecting object 32145 info ...
# Collecting object 32181 info ...
# Collecting object 32144 info ...
# Collecting object 32182 info ...
# Collecting object 32194 info ...
# Collecting object 18173 info ...
# Collecting object 43297 info ...
# Collecting object 39868 info ...
# Collecting object 39851 info ...
# Collecting object 39890 info ...
# Collecting object 39848 info ...
# Collecting object 39856 info ...
# Collecting object 39906 info ...
# Collecting object 39840 info ...
# Collecting object 39895 info ...
# Collecting object 39859 info ...
# Collecting object 39894 info ...
# Collecting object 39886 info ...
# Collecting object 39844 info ...
# Collecting object 39871 info ...
# Collecting object 39883 info ...
# Collecting object 39845 info ...
# Collecting object 39881 info ...
# Collecting object 39888 info ...
# Collecting object 39885 info ...
# Collecting object 39847 info ...
# Collecting object 39861 info ...
# Collecting object 39900 info ...
# Collecting object 39896 info ...
# Collecting object 39865 info ...
# Collecting object 39857 info ...
# Collecting object 39867 info ...
# Collecting object 39889 info ...
# Collecting object 39869 info ...
# Collecting object 39905 info ...
# Collecting object 39860 info ...
# Collecting object 39884 info ...
# Collecting object 39852 info ...
# Collecting object 39854 info ...
# Collecting object 39892 info ...
# Collecting object 39897 info ...
# Collecting object 39873 info ...
# Collecting object 39901 info ...
# Collecting object 39891 info ...
# Collecting object 39843 info ...
# Collecting object 39870 info ...
# Collecting object 39893 info ...
# Collecting object 39862 info ...
# Collecting object 39841 info ...
# Collecting object 39882 info ...
# Collecting object 39899 info ...
# Collecting object 39880 info ...
# Collecting object 39903 info ...
# Collecting object 39876 info ...
# Collecting object 39898 info ...
# Collecting object 39907 info ...
# Collecting object 39875 info ...
# Collecting object 39877 info ...
# Collecting object 39878 info ...
# Collecting object 39904 info ...
# Collecting object 39874 info ...
# Collecting object 39855 info ...
# Collecting object 39849 info ...
# Collecting object 39864 info ...
# Collecting object 39872 info ...
# Collecting object 39858 info ...
# Collecting object 39866 info ...
# Collecting object 39850 info ...
# Collecting object 39853 info ...
# Collecting object 39842 info ...
# Collecting object 39887 info ...
# Collecting object 39846 info ...
# Collecting object 39902 info ...
# Collecting object 39879 info ...
# Collecting object 39863 info ...
# Collecting object 38685 info ...
# Collecting object 38687 info ...
# Collecting object 38686 info ...
# Collecting object 41404 info ...
# Collecting object 25970 info ...
# Collecting object 13204 info ...
# Collecting object 13203 info ...
# Collecting object 9189 info ...
# Collecting object 32617 info ...
# Collecting object 11395 info ...
# Collecting object 25576 info ...
# Collecting object 41000 info ...
# Collecting object 40008 info ...
# Collecting object 44055 info ...
# Collecting object 27226 info ...
# Collecting object 44084 info ...
# Collecting object 42428 info ...
# Collecting object 42527 info ...
# Collecting object 44124 info ...
# Collecting object 44123 info ...
# Collecting object 44122 info ...
# Collecting object 42729 info ...
# Collecting object 44120 info ...
# Collecting object 44121 info ...
# Collecting object 20030 info ...
# Collecting object 19980 info ...
# Collecting object 18606 info ...
# Collecting object 41395 info ...
# Collecting object 41392 info ...
# Collecting object 36989 info ...
# Collecting object 41394 info ...
# Collecting object 41397 info ...
# Collecting object 29363 info ...
# Collecting object 36986 info ...
# Collecting object 41223 info ...
# Collecting object 36990 info ...
# Collecting object 41227 info ...
# Collecting object 41390 info ...
# Collecting object 29364 info ...
# Collecting object 29355 info ...
# Collecting object 18609 info ...
# Collecting object 18608 info ...
# Collecting object 41226 info ...
# Collecting object 41400 info ...
# Collecting object 36992 info ...
# Collecting object 29359 info ...
# Collecting object 40393 info ...
# Collecting object 41391 info ...
# Collecting object 40392 info ...
# Collecting object 29352 info ...
# Collecting object 36991 info ...
# Collecting object 41222 info ...
# Collecting object 41224 info ...
# Collecting object 36988 info ...
# Collecting object 41393 info ...
# Collecting object 36993 info ...
# Collecting object 41401 info ...
# Collecting object 41246 info ...
# Collecting object 29357 info ...
# Collecting object 36994 info ...
# Collecting object 29361 info ...
# Collecting object 29356 info ...
# Collecting object 29350 info ...
# Collecting object 36987 info ...
# Collecting object 29353 info ...
# Collecting object 29358 info ...
# Collecting object 41221 info ...
# Collecting object 18602 info ...
# Collecting object 18610 info ...
# Collecting object 29354 info ...
# Collecting object 29360 info ...
# Collecting object 41389 info ...
# Collecting object 41225 info ...
# Collecting object 41396 info ...
# Collecting object 41398 info ...
# Collecting object 41402 info ...
# Collecting object 41247 info ...
# Collecting object 29362 info ...
# Collecting object 41399 info ...
# Collecting object 29351 info ...
# Collecting object 18607 info ...
# Collecting object 40539 info ...
# Collecting object 31870 info ...
# Collecting object 22633 info ...
# Collecting object 42022 info ...
# Collecting object 38107 info ...
# Collecting object 31313 info ...
# Collecting object 43268 info ...
# Collecting object 37944 info ...
# Collecting object 37943 info ...
# Collecting object 35065 info ...
# Collecting object 7440 info ...
# Collecting object 15125 info ...
# Collecting object 15124 info ...
# Collecting object 14938 info ...
# Collecting object 15123 info ...
# Collecting object 13922 info ...
# Collecting object 22516 info ...
# Collecting object 21888 info ...
# Collecting object 17415 info ...
# Collecting object 41447 info ...
# Collecting object 9461 info ...
# Collecting object 25836 info ...
# Collecting object 43254 info ...
# Collecting object 19204 info ...
# Collecting object 20188 info ...
# Collecting object 19199 info ...
# Collecting object 9282 info ...
# Collecting object 20190 info ...
# Collecting object 32269 info ...
# Collecting object 26753 info ...
# Collecting object 22612 info ...
# Collecting object 22621 info ...
# Collecting object 22609 info ...
# Collecting object 22611 info ...
# Collecting object 22588 info ...
# Collecting object 22604 info ...
# Collecting object 22606 info ...
# Collecting object 22614 info ...
# Collecting object 22610 info ...
# Collecting object 22591 info ...
# Collecting object 22617 info ...
# Collecting object 22613 info ...
# Collecting object 22623 info ...
# Collecting object 22583 info ...
# Collecting object 22626 info ...
# Collecting object 22607 info ...
# Collecting object 22619 info ...
# Collecting object 22584 info ...
# Collecting object 22605 info ...
# Collecting object 22618 info ...
# Collecting object 22624 info ...
# Collecting object 22587 info ...
# Collecting object 22592 info ...
# Collecting object 22608 info ...
# Collecting object 22622 info ...
# Collecting object 22616 info ...
# Collecting object 22615 info ...
# Collecting object 28425 info ...
# Collecting object 32735 info ...
# Collecting object 32119 info ...
# Collecting object 42114 info ...
# Collecting object 38764 info ...
# Collecting object 21329 info ...
# Collecting object 13495 info ...
# Collecting object 31446 info ...
# Collecting object 31444 info ...
# Collecting object 31445 info ...
# Collecting object 31442 info ...
# Collecting object 31443 info ...
# Collecting object 34950 info ...
# Collecting object 9341 info ...
# Collecting object 44161 info ...
# Collecting object 43836 info ...
# Collecting object 41267 info ...
# Collecting object 40192 info ...
# Collecting object 41266 info ...
# Collecting object 43450 info ...
# Collecting object 43832 info ...
# Collecting object 35646 info ...
# Collecting object 43451 info ...
# Collecting object 37716 info ...
# Collecting object 25657 info ...
# Collecting object 25656 info ...
# Collecting object 32926 info ...
# Collecting object 11531 info ...
# Collecting object 11527 info ...
# Collecting object 8787 info ...
# Collecting object 11534 info ...
# Collecting object 8792 info ...
# Collecting object 11529 info ...
# Collecting object 13562 info ...
# Collecting object 13563 info ...
# Collecting object 13564 info ...
# Collecting object 13568 info ...
# Collecting object 13559 info ...
# Collecting object 13560 info ...
# Collecting object 13576 info ...
# Collecting object 13578 info ...
# Collecting object 13573 info ...
# Collecting object 13565 info ...
# Collecting object 13566 info ...
# Collecting object 13574 info ...
# Collecting object 13569 info ...
# Collecting object 13567 info ...
# Collecting object 13572 info ...
# Collecting object 13570 info ...
# Collecting object 13561 info ...
# Collecting object 13575 info ...
# Collecting object 13577 info ...
# Collecting object 13571 info ...
# Collecting object 37903 info ...
# Collecting object 37901 info ...
# Collecting object 37904 info ...
# Collecting object 37902 info ...
# Collecting object 37898 info ...
# Collecting object 37900 info ...
# Collecting object 37899 info ...
# Collecting object 43427 info ...
# Collecting object 22405 info ...
# Collecting object 32280 info ...
# Collecting object 35044 info ...
# Collecting object 30646 info ...
# Collecting object 30647 info ...
# Collecting object 30644 info ...
# Collecting object 30645 info ...
# Collecting object 30632 info ...
# Collecting object 30333 info ...
# Collecting object 23131 info ...
# Collecting object 30088 info ...
# Collecting object 851 info ...
# Collecting object 30144 info ...
# Collecting object 6392 info ...
# Collecting object 6388 info ...
# Collecting object 6393 info ...
# Collecting object 37733 info ...
# Collecting object 37742 info ...
# Collecting object 28036 info ...
# Collecting object 32611 info ...
# Collecting object 29010 info ...
# Collecting object 28980 info ...
# Collecting object 42911 info ...
# Collecting object 42355 info ...
# Collecting object 44419 info ...
# Collecting object 27384 info ...
# Collecting object 42610 info ...
# Collecting object 17172 info ...
# Collecting object 34899 info ...
# Collecting object 34900 info ...
# Collecting object 34898 info ...
# Collecting object 30850 info ...
# Collecting object 38758 info ...
# Collecting object 41943 info ...
# Collecting object 28766 info ...
# Collecting object 28767 info ...
# Collecting object 38757 info ...
# Collecting object 42581 info ...
# Collecting object 42354 info ...
# Collecting object 41274 info ...
# Collecting object 17823 info ...
# Collecting object 17824 info ...
# Collecting object 40493 info ...
# Collecting object 40497 info ...
# Collecting object 41626 info ...
# Collecting object 40085 info ...
# Collecting object 36864 info ...
# Collecting object 37263 info ...
# Collecting object 38035 info ...
# Collecting object 38034 info ...
# Collecting object 38036 info ...
# Collecting object 31327 info ...
# Collecting object 31328 info ...
# Collecting object 40084 info ...
# Collecting object 30887 info ...
# Collecting object 36904 info ...
# Collecting object 36903 info ...
# Collecting object 42246 info ...
# Collecting object 42477 info ...
# Collecting object 38486 info ...
# Collecting object 42475 info ...
# Collecting object 20280 info ...
# Collecting object 4923 info ...
# Collecting object 26031 info ...
# Collecting object 26034 info ...
# Collecting object 26035 info ...
# Collecting object 37469 info ...
# Collecting object 27840 info ...
# Collecting object 27838 info ...
# Collecting object 37467 info ...
# Collecting object 37204 info ...
# Collecting object 41230 info ...
# Collecting object 36062 info ...
# Collecting object 21626 info ...
# Collecting object 5284 info ...
# Collecting object 38206 info ...
# Collecting object 1601 info ...
# Collecting object 1600 info ...
# Collecting object 25238 info ...
# Collecting object 8224 info ...
# Collecting object 19437 info ...
# Collecting object 8241 info ...
# Collecting object 19438 info ...
# Collecting object 43064 info ...
# Collecting object 43063 info ...
# Collecting object 2718 info ...
# Collecting object 3064 info ...
# Collecting object 32083 info ...
# Collecting object 31640 info ...
# Collecting object 32084 info ...
# Collecting object 32055 info ...
# Collecting object 28447 info ...
# Collecting object 28448 info ...
# Collecting object 27918 info ...
# Collecting object 27917 info ...
# Collecting object 27924 info ...
# Collecting object 27922 info ...
# Collecting object 27925 info ...
# Collecting object 27921 info ...
# Collecting object 27920 info ...
# Collecting object 27923 info ...
# Collecting object 27919 info ...
# Collecting object 27916 info ...
# Collecting object 44007 info ...
# Collecting object 37757 info ...
# Collecting object 42170 info ...
# Collecting object 43627 info ...
# Collecting object 41668 info ...
# Collecting object 39770 info ...
# Collecting object 42067 info ...
# Collecting object 11634 info ...
# Collecting object 36807 info ...
# Collecting object 11657 info ...
# Collecting object 11095 info ...
# Collecting object 11302 info ...
# Collecting object 10415 info ...
# Collecting object 11638 info ...
# Collecting object 18758 info ...
# Collecting object 18756 info ...
# Collecting object 13669 info ...
# Collecting object 18764 info ...
# Collecting object 37139 info ...
# Collecting object 18754 info ...
# Collecting object 18763 info ...
# Collecting object 18762 info ...
# Collecting object 7196 info ...
# Collecting object 18761 info ...
# Collecting object 36533 info ...
# Collecting object 18759 info ...
# Collecting object 7198 info ...
# Collecting object 40756 info ...
# Collecting object 7199 info ...
# Collecting object 18753 info ...
# Collecting object 36707 info ...
# Collecting object 18760 info ...
# Collecting object 44060 info ...
# Collecting object 18750 info ...
# Collecting object 36460 info ...
# Collecting object 37072 info ...
# Collecting object 18755 info ...
# Collecting object 44061 info ...
# Collecting object 13714 info ...
# Collecting object 44059 info ...
# Collecting object 7197 info ...
# Collecting object 18757 info ...
# Collecting object 44058 info ...
# Collecting object 27145 info ...
# Collecting object 19053 info ...
# Collecting object 19050 info ...
# Collecting object 19054 info ...
# Collecting object 10351 info ...
# Collecting object 42594 info ...
# Collecting object 41106 info ...
# Collecting object 38847 info ...
# Collecting object 43932 info ...
# Collecting object 39811 info ...
# Collecting object 36397 info ...
# Collecting object 36449 info ...
# Collecting object 11242 info ...
# Collecting object 44410 info ...
# Collecting object 36036 info ...
# Collecting object 37975 info ...
# Collecting object 25912 info ...
# Collecting object 25913 info ...
# Collecting object 37167 info ...
# Collecting object 37402 info ...
# Collecting object 24162 info ...
# Collecting object 41244 info ...
# Collecting object 41245 info ...
# Collecting object 41243 info ...
# Collecting object 42797 info ...
# Collecting object 4695 info ...
# Collecting object 4693 info ...
# Collecting object 4692 info ...
# Collecting object 4694 info ...
# Collecting object 21740 info ...
# Collecting object 42242 info ...
# Collecting object 42213 info ...
# Collecting object 40742 info ...
# Collecting object 43877 info ...
# Collecting object 25725 info ...
# Collecting object 12791 info ...
# Collecting object 12793 info ...
# Collecting object 12792 info ...
# Collecting object 10590 info ...
# Collecting object 31817 info ...
# Collecting object 31818 info ...
# Collecting object 24732 info ...
# Collecting object 24731 info ...
# Collecting object 40479 info ...
# Collecting object 40480 info ...
# Collecting object 40478 info ...
# Collecting object 24730 info ...
# Collecting object 3224 info ...
# Collecting object 40144 info ...
# Collecting object 25298 info ...
# Collecting object 8670 info ...
# Collecting object 7531 info ...
# Collecting object 30123 info ...
# Collecting object 4782 info ...
# Collecting object 4783 info ...
# Collecting object 32344 info ...
# Collecting object 32346 info ...
# Collecting object 19929 info ...
# Collecting object 32347 info ...
# Collecting object 32348 info ...
# Collecting object 19927 info ...
# Collecting object 32345 info ...
# Collecting object 19925 info ...
# Collecting object 19926 info ...
# Collecting object 19930 info ...
# Collecting object 19924 info ...
# Collecting object 32343 info ...
# Collecting object 19923 info ...
# Collecting object 7136 info ...
# Collecting object 7139 info ...
# Collecting object 7138 info ...
# Collecting object 7135 info ...
# Collecting object 33247 info ...
# Collecting object 18884 info ...
# Collecting object 30918 info ...
# Collecting object 32629 info ...
# Collecting object 43501 info ...
# Collecting object 34521 info ...
# Collecting object 34522 info ...
# Collecting object 31021 info ...
# Collecting object 34847 info ...
# Collecting object 17392 info ...
# Collecting object 17411 info ...
# Collecting object 17406 info ...
# Collecting object 17404 info ...
# Collecting object 17397 info ...
# Collecting object 17410 info ...
# Collecting object 17403 info ...
# Collecting object 17395 info ...
# Collecting object 17396 info ...
# Collecting object 17394 info ...
# Collecting object 17402 info ...
# Collecting object 17407 info ...
# Collecting object 17398 info ...
# Collecting object 17409 info ...
# Collecting object 17405 info ...
# Collecting object 17399 info ...
# Collecting object 17408 info ...
# Collecting object 10977 info ...
# Collecting object 11019 info ...
# Collecting object 32604 info ...
# Collecting object 11015 info ...
# Collecting object 11020 info ...
# Collecting object 11010 info ...
# Collecting object 4279 info ...
# Collecting object 32603 info ...
# Collecting object 4284 info ...
# Collecting object 4285 info ...
# Collecting object 11026 info ...
# Collecting object 11023 info ...
# Collecting object 11011 info ...
# Collecting object 32606 info ...
# Collecting object 4280 info ...
# Collecting object 10983 info ...
# Collecting object 4283 info ...
# Collecting object 4286 info ...
# Collecting object 10985 info ...
# Collecting object 11022 info ...
# Collecting object 11005 info ...
# Collecting object 32608 info ...
# Collecting object 11006 info ...
# Collecting object 4287 info ...
# Collecting object 11009 info ...
# Collecting object 10986 info ...
# Collecting object 11017 info ...
# Collecting object 4281 info ...
# Collecting object 11018 info ...
# Collecting object 32605 info ...
# Collecting object 10976 info ...
# Collecting object 10981 info ...
# Collecting object 11012 info ...
# Collecting object 11021 info ...
# Collecting object 10978 info ...
# Collecting object 10984 info ...
# Collecting object 11016 info ...
# Collecting object 10987 info ...
# Collecting object 10982 info ...
# Collecting object 11025 info ...
# Collecting object 10980 info ...
# Collecting object 11007 info ...
# Collecting object 4282 info ...
# Collecting object 11013 info ...
# Collecting object 11008 info ...
# Collecting object 10979 info ...
# Collecting object 32607 info ...
# Collecting object 11014 info ...
# Collecting object 11024 info ...
# Collecting object 43491 info ...
# Collecting object 25252 info ...
# Collecting object 41834 info ...
# Collecting object 23558 info ...
# Collecting object 23556 info ...
# Collecting object 4654 info ...
# Collecting object 24858 info ...
# Collecting object 25872 info ...
# Collecting object 39317 info ...
# Collecting object 39049 info ...
# Collecting object 43675 info ...
# Collecting object 24234 info ...
# Collecting object 24222 info ...
# Collecting object 37859 info ...
# Collecting object 21402 info ...
# Collecting object 41945 info ...
# Collecting object 41944 info ...
# Collecting object 36726 info ...
# Collecting object 40843 info ...
# Collecting object 31802 info ...
# Collecting object 36727 info ...
# Collecting object 31801 info ...
# Collecting object 31805 info ...
# Collecting object 31800 info ...
# Collecting object 40842 info ...
# Collecting object 31804 info ...
# Collecting object 36725 info ...
# Collecting object 31803 info ...
# Collecting object 40841 info ...
# Collecting object 39796 info ...
# Collecting object 2517 info ...
# Collecting object 24085 info ...
# Collecting object 24070 info ...
# Collecting object 2826 info ...
# Collecting object 36567 info ...
# Collecting object 29436 info ...
# Collecting object 29439 info ...
# Collecting object 2458 info ...
# Collecting object 37372 info ...
# Collecting object 37371 info ...
# Collecting object 36956 info ...
# Collecting object 36954 info ...
# Collecting object 36955 info ...
# Collecting object 28563 info ...
# Collecting object 28530 info ...
# Collecting object 9588 info ...
# Collecting object 31298 info ...
# Collecting object 29065 info ...
# Collecting object 42059 info ...
# Collecting object 23733 info ...
# Collecting object 24498 info ...
# Collecting object 24501 info ...
# Collecting object 24500 info ...
# Collecting object 24502 info ...
# Collecting object 20507 info ...
# Collecting object 23550 info ...
# Collecting object 41147 info ...
# Collecting object 23551 info ...
# Collecting object 33238 info ...
# Collecting object 1527 info ...
# Collecting object 8652 info ...
# Collecting object 21504 info ...
# Collecting object 42903 info ...
# Collecting object 42904 info ...
# Collecting object 39000 info ...
# Collecting object 11725 info ...
# Collecting object 22178 info ...
# Collecting object 22171 info ...
# Collecting object 22183 info ...
# Collecting object 22192 info ...
# Collecting object 36846 info ...
# Collecting object 35298 info ...
# Collecting object 40676 info ...
# Collecting object 36661 info ...
# Collecting object 36660 info ...
# Collecting object 36663 info ...
# Collecting object 36665 info ...
# Collecting object 36664 info ...
# Collecting object 24406 info ...
# Collecting object 42929 info ...
# Collecting object 12963 info ...
# Collecting object 34180 info ...
# Collecting object 41650 info ...
# Collecting object 41648 info ...
# Collecting object 41645 info ...
# Collecting object 41646 info ...
# Collecting object 41651 info ...
# Collecting object 41644 info ...
# Collecting object 41656 info ...
# Collecting object 41647 info ...
# Collecting object 41649 info ...
# Collecting object 34971 info ...
# Collecting object 34973 info ...
# Collecting object 34972 info ...
# Collecting object 34974 info ...
# Collecting object 34970 info ...
# Collecting object 25098 info ...
# Collecting object 25099 info ...
# Collecting object 25096 info ...
# Collecting object 25100 info ...
# Collecting object 25097 info ...
# Collecting object 3333 info ...
# Collecting object 22720 info ...
# Collecting object 27855 info ...
# Collecting object 38360 info ...
# Collecting object 26158 info ...
# Collecting object 41658 info ...
# Collecting object 43811 info ...
# Collecting object 26157 info ...
# Collecting object 31385 info ...
# Collecting object 42635 info ...
# Collecting object 42638 info ...
# Collecting object 42637 info ...
# Collecting object 42636 info ...
# Collecting object 26460 info ...
# Collecting object 3595 info ...
# Collecting object 5811 info ...
# Collecting object 3312 info ...
# Collecting object 3310 info ...
# Collecting object 3311 info ...
# Collecting object 3313 info ...
# Collecting object 36670 info ...
# Collecting object 36669 info ...
# Collecting object 36671 info ...
# Collecting object 30622 info ...
# Collecting object 30623 info ...
# Collecting object 23206 info ...
# Collecting object 9384 info ...
# Collecting object 26243 info ...
# Collecting object 26247 info ...
# Collecting object 41269 info ...
# Collecting object 41270 info ...
# Collecting object 41271 info ...
# Collecting object 26466 info ...
# Collecting object 15822 info ...
# Collecting object 34111 info ...
# Collecting object 38864 info ...
# Collecting object 38865 info ...
# Collecting object 38862 info ...
# Collecting object 30962 info ...
# Collecting object 27944 info ...
# Collecting object 27946 info ...
# Collecting object 27945 info ...
# Collecting object 27943 info ...
# Collecting object 29005 info ...
# Collecting object 42678 info ...
# Collecting object 36585 info ...
# Collecting object 43204 info ...
# Collecting object 23983 info ...
# Collecting object 23984 info ...
# Collecting object 23981 info ...
# Collecting object 23982 info ...
# Collecting object 39268 info ...
# Collecting object 35418 info ...
# Collecting object 41739 info ...
# Collecting object 20623 info ...
# Collecting object 20625 info ...
# Collecting object 32907 info ...
# Collecting object 17366 info ...
# Collecting object 44462 info ...
# Collecting object 17375 info ...
# Collecting object 17373 info ...
# Collecting object 17372 info ...
# Collecting object 44463 info ...
# Collecting object 17368 info ...
# Collecting object 17374 info ...
# Collecting object 44464 info ...
# Collecting object 44460 info ...
# Collecting object 44461 info ...
# Collecting object 44465 info ...
# Collecting object 31696 info ...
# Collecting object 13222 info ...
# Collecting object 36330 info ...
# Collecting object 12819 info ...
# Collecting object 12889 info ...
# Collecting object 12893 info ...
# Collecting object 26720 info ...
# Collecting object 40264 info ...
# Collecting object 26797 info ...
# Collecting object 32736 info ...
# Collecting object 39383 info ...
# Collecting object 39411 info ...
# Collecting object 39398 info ...
# Collecting object 39380 info ...
# Collecting object 39384 info ...
# Collecting object 39400 info ...
# Collecting object 39408 info ...
# Collecting object 39379 info ...
# Collecting object 39404 info ...
# Collecting object 39403 info ...
# Collecting object 39388 info ...
# Collecting object 39393 info ...
# Collecting object 39395 info ...
# Collecting object 39402 info ...
# Collecting object 39392 info ...
# Collecting object 39391 info ...
# Collecting object 39386 info ...
# Collecting object 39387 info ...
# Collecting object 39407 info ...
# Collecting object 39389 info ...
# Collecting object 39409 info ...
# Collecting object 39396 info ...
# Collecting object 39385 info ...
# Collecting object 39377 info ...
# Collecting object 39390 info ...
# Collecting object 39399 info ...
# Collecting object 39371 info ...
# Collecting object 39394 info ...
# Collecting object 39410 info ...
# Collecting object 39405 info ...
# Collecting object 39412 info ...
# Collecting object 39406 info ...
# Collecting object 39413 info ...
# Collecting object 39397 info ...
# Collecting object 39401 info ...
# Collecting object 36896 info ...
# Collecting object 36895 info ...
# Collecting object 6159 info ...
# Collecting object 20804 info ...
# Collecting object 27539 info ...
# Collecting object 43497 info ...
# Collecting object 43681 info ...
# Collecting object 43680 info ...
# Collecting object 38754 info ...
# Collecting object 40344 info ...
# ...
# Collecting object 31332 info ...
# Collecting object 42033 info ...
# Collecting object 41949 info ...
# Collecting object 36804 info ...
# Collecting object 42654 info ...
# Collecting object 36805 info ...
# Collecting object 42665 info ...
# Collecting object 9256 info ...
# Collecting object 23727 info ...
# Collecting object 24506 info ...
# Collecting object 23732 info ...
# Collecting object 22824 info ...
# Collecting object 37852 info ...
# Collecting object 37170 info ...
# Collecting object 37876 info ...
# Collecting object 35024 info ...
# Collecting object 35023 info ...
# Collecting object 31944 info ...
# Collecting object 31943 info ...
# Collecting object 24954 info ...
# Collecting object 32154 info ...
# Collecting object 2152 info ...
# Collecting object 35539 info ...
# Collecting object 35538 info ...
# Collecting object 26926 info ...
# Collecting object 9035 info ...
# Collecting object 9030 info ...
# Collecting object 9048 info ...
# Collecting object 9036 info ...
# Collecting object 9052 info ...
# Collecting object 9031 info ...
# Collecting object 9049 info ...
# Collecting object 9043 info ...
# Collecting object 9047 info ...
# Collecting object 9033 info ...
# Collecting object 16298 info ...
# Collecting object 9038 info ...
# Collecting object 9046 info ...
# Collecting object 9051 info ...
# Collecting object 9045 info ...
# Collecting object 9041 info ...
# Collecting object 16300 info ...
# Collecting object 16302 info ...
# Collecting object 16301 info ...
# Collecting object 9037 info ...
# Collecting object 16299 info ...
# Collecting object 9032 info ...
# Collecting object 9042 info ...
# Collecting object 9039 info ...
# Collecting object 9050 info ...
# Collecting object 16297 info ...
# Collecting object 9034 info ...
# Collecting object 9053 info ...
# Collecting object 9044 info ...
# Collecting object 9040 info ...
# Collecting object 17935 info ...
# Collecting object 31236 info ...
# Collecting object 31233 info ...
# Collecting object 31234 info ...
# Collecting object 31235 info ...
# Collecting object 16929 info ...
# Collecting object 16930 info ...
# Collecting object 34611 info ...
# Collecting object 40958 info ...
# Collecting object 22642 info ...
# Collecting object 22641 info ...
# Collecting object 36174 info ...
# Collecting object 31785 info ...
# Collecting object 30610 info ...
# Collecting object 30611 info ...
# Collecting object 20157 info ...
# Collecting object 40503 info ...
# Collecting object 40473 info ...
# Collecting object 43695 info ...
# Collecting object 42017 info ...
# Collecting object 27970 info ...
# Collecting object 27971 info ...
# Collecting object 30574 info ...
# Collecting object 30667 info ...
# Collecting object 31119 info ...
# Collecting object 29832 info ...
# Collecting object 28892 info ...
# Collecting object 29994 info ...
# Collecting object 44350 info ...
# Collecting object 44351 info ...
# Collecting object 5945 info ...
# Collecting object 29403 info ...
# Collecting object 22945 info ...
# Collecting object 5360 info ...
# Collecting object 19730 info ...
# Collecting object 21462 info ...
# Collecting object 37612 info ...
# Collecting object 41136 info ...
# Collecting object 34213 info ...
# Collecting object 43970 info ...
# Collecting object 43971 info ...
# Collecting object 44202 info ...
# Collecting object 44283 info ...
# Collecting object 44280 info ...
# Collecting object 44200 info ...
# Collecting object 44289 info ...
# Collecting object 44275 info ...
# Collecting object 44286 info ...
# Collecting object 44279 info ...
# Collecting object 44263 info ...
# Collecting object 44268 info ...
# Collecting object 44288 info ...
# Collecting object 44203 info ...
# Collecting object 44282 info ...
# Collecting object 44267 info ...
# Collecting object 44201 info ...
# Collecting object 44205 info ...
# Collecting object 44281 info ...
# Collecting object 44262 info ...
# Collecting object 44204 info ...
# Collecting object 44270 info ...
# Collecting object 44261 info ...
# Collecting object 44284 info ...
# Collecting object 38800 info ...
# Collecting object 44271 info ...
# Collecting object 44260 info ...
# Collecting object 44266 info ...
# Collecting object 44273 info ...
# Collecting object 44285 info ...
# Collecting object 44198 info ...
# Collecting object 44269 info ...
# Collecting object 44276 info ...
# Collecting object 44206 info ...
# Collecting object 44199 info ...
# Collecting object 44272 info ...
# Collecting object 44290 info ...
# Collecting object 39155 info ...
# Collecting object 35078 info ...
# Collecting object 36155 info ...
# Collecting object 26196 info ...
# Collecting object 25343 info ...
# Collecting object 27304 info ...
# Collecting object 32267 info ...
# Collecting object 32268 info ...
# Collecting object 38707 info ...
# Collecting object 23041 info ...
# Collecting object 12572 info ...
# Collecting object 24785 info ...
# Collecting object 43625 info ...
# Collecting object 25961 info ...
# Collecting object 25962 info ...
# Collecting object 41488 info ...
# Collecting object 22759 info ...
# Collecting object 22758 info ...
# Collecting object 41541 info ...
# Collecting object 41141 info ...
# Collecting object 41139 info ...
# Collecting object 41140 info ...
# Collecting object 42350 info ...
# Collecting object 44016 info ...
# Collecting object 42351 info ...
# Collecting object 26038 info ...
# Collecting object 43486 info ...
# Collecting object 8225 info ...
# Collecting object 8716 info ...
# Collecting object 40142 info ...
# Collecting object 12656 info ...
# Collecting object 12685 info ...
# Collecting object 40136 info ...
# Collecting object 28091 info ...
# Collecting object 8723 info ...
# Collecting object 40140 info ...
# Collecting object 27996 info ...
# Collecting object 40134 info ...
# Collecting object 40137 info ...
# Collecting object 8712 info ...
# Collecting object 40133 info ...
# Collecting object 27032 info ...
# Collecting object 28090 info ...
# Collecting object 27011 info ...
# Collecting object 8244 info ...
# Collecting object 6098 info ...
# Collecting object 27014 info ...
# Collecting object 27997 info ...
# Collecting object 28092 info ...
# Collecting object 40143 info ...
# Collecting object 12721 info ...
# Collecting object 40132 info ...
# Collecting object 27035 info ...
# Collecting object 27009 info ...
# Collecting object 8229 info ...
# Collecting object 40135 info ...
# Collecting object 27034 info ...
# Collecting object 12655 info ...
# Collecting object 27010 info ...
# Collecting object 27033 info ...
# Collecting object 37652 info ...
# Collecting object 27994 info ...
# Collecting object 12659 info ...
# Collecting object 12695 info ...
# Collecting object 27015 info ...
# Collecting object 28093 info ...
# Collecting object 41546 info ...
# Collecting object 5630 info ...
# Collecting object 12652 info ...
# Collecting object 12654 info ...
# Collecting object 37653 info ...
# Collecting object 8720 info ...
# Collecting object 41545 info ...
# Collecting object 8714 info ...
# Collecting object 8724 info ...
# Collecting object 8715 info ...
# Collecting object 8227 info ...
# Collecting object 26537 info ...
# Collecting object 28089 info ...
# Collecting object 27012 info ...
# Collecting object 27995 info ...
# Collecting object 40141 info ...
# Collecting object 36500 info ...
# Collecting object 38070 info ...
# Collecting object 42155 info ...
# Collecting object 42153 info ...
# Collecting object 36741 info ...
# Collecting object 38071 info ...
# Collecting object 38072 info ...
# Collecting object 42154 info ...
# Collecting object 36501 info ...
# Collecting object 36745 info ...
# Collecting object 36742 info ...
# Collecting object 36744 info ...
# Collecting object 36743 info ...
# Collecting object 36502 info ...
# Collecting object 40748 info ...
# Collecting object 44425 info ...
# Collecting object 43810 info ...
# Collecting object 28757 info ...
# Collecting object 28755 info ...
# Collecting object 28754 info ...
# Collecting object 43674 info ...
# Collecting object 39103 info ...
# Collecting object 17578 info ...
# Collecting object 29211 info ...
# Collecting object 30264 info ...
# Collecting object 13697 info ...
# Collecting object 13698 info ...
# Collecting object 13701 info ...
# Collecting object 13699 info ...
# Collecting object 13700 info ...
# Collecting object 44291 info ...
# Collecting object 8992 info ...
# Collecting object 23773 info ...
# Collecting object 42039 info ...
# Collecting object 24174 info ...
# Collecting object 24184 info ...
# Collecting object 24177 info ...
# Collecting object 24175 info ...
# Collecting object 12909 info ...
# Collecting object 29799 info ...
# Collecting object 32336 info ...
# Collecting object 32335 info ...
# Collecting object 6421 info ...
# Collecting object 27432 info ...
# Collecting object 27431 info ...
# Collecting object 11277 info ...
# Collecting object 12344 info ...
# Collecting object 11611 info ...
# Collecting object 11659 info ...
# Collecting object 11275 info ...
# Collecting object 12343 info ...
# Collecting object 11660 info ...
# Collecting object 11279 info ...
# Collecting object 11274 info ...
# Collecting object 12345 info ...
# Collecting object 11558 info ...
# Collecting object 11661 info ...
# Collecting object 12346 info ...
# Collecting object 11656 info ...
# Collecting object 11610 info ...
# Collecting object 11281 info ...
# Collecting object 11283 info ...
# Collecting object 11560 info ...
# Collecting object 11276 info ...
# Collecting object 11559 info ...
# Collecting object 11282 info ...
# Collecting object 12216 info ...
# Collecting object 12099 info ...
# Collecting object 6889 info ...
# Collecting object 43305 info ...
# Collecting object 43306 info ...
# Collecting object 43308 info ...
# Collecting object 40705 info ...
# Collecting object 40704 info ...
# Collecting object 43307 info ...
# Collecting object 4928 info ...
# Collecting object 4931 info ...
# Collecting object 4932 info ...
# Collecting object 4936 info ...
# Collecting object 4943 info ...
# Collecting object 4933 info ...
# Collecting object 4942 info ...
# Collecting object 33386 info ...
# Collecting object 33387 info ...
# Collecting object 4938 info ...
# Collecting object 30547 info ...
# Collecting object 30545 info ...
# Collecting object 30544 info ...
# Collecting object 14528 info ...
# Collecting object 30549 info ...
# Collecting object 7708 info ...
# Collecting object 30543 info ...
# Collecting object 11459 info ...
# Collecting object 30546 info ...
# Collecting object 30548 info ...
# Collecting object 30550 info ...
# Collecting object 31074 info ...
# Collecting object 32463 info ...
# Collecting object 32462 info ...
# Collecting object 28372 info ...
# Collecting object 29891 info ...
# Collecting object 27545 info ...
# Collecting object 29893 info ...
# Collecting object 29892 info ...
# Collecting object 37771 info ...
# Collecting object 37772 info ...
# Collecting object 28229 info ...
# Collecting object 26204 info ...
# Collecting object 11885 info ...
# Collecting object 25574 info ...
# Collecting object 25575 info ...
# Collecting object 25573 info ...
# Collecting object 44215 info ...
# Collecting object 44216 info ...
# Collecting object 44208 info ...
# Collecting object 44211 info ...
# Collecting object 44212 info ...
# Collecting object 44209 info ...
# Collecting object 44213 info ...
# Collecting object 44210 info ...
# Collecting object 44214 info ...
# Collecting object 44207 info ...
# Collecting object 31660 info ...
# Collecting object 31658 info ...
# Collecting object 31659 info ...
# Collecting object 23760 info ...
# Collecting object 39158 info ...
# Collecting object 31343 info ...
# Collecting object 31342 info ...
# Collecting object 24336 info ...
# Collecting object 24649 info ...
# Collecting object 24648 info ...
# Collecting object 41032 info ...
# Collecting object 38948 info ...
# Collecting object 38949 info ...
# Collecting object 44113 info ...
# Collecting object 30560 info ...
# Collecting object 2777 info ...
# Collecting object 24623 info ...
# Collecting object 24625 info ...
# Collecting object 24620 info ...
# Collecting object 24624 info ...
# Collecting object 24626 info ...
# Collecting object 24627 info ...
# Collecting object 24621 info ...
# Collecting object 24619 info ...
# Collecting object 24622 info ...
# Collecting object 10884 info ...
# Collecting object 36674 info ...
# Collecting object 23262 info ...
# Collecting object 2599 info ...
# Collecting object 2323 info ...
# Collecting object 2591 info ...
# Collecting object 21158 info ...
# Collecting object 21156 info ...
# Collecting object 21157 info ...
# Collecting object 20866 info ...
# Collecting object 6896 info ...
# Collecting object 43628 info ...
# Collecting object 43198 info ...
# Collecting object 40203 info ...
# Collecting object 22214 info ...
# Collecting object 22216 info ...
# Collecting object 22215 info ...
# Collecting object 22213 info ...
# Collecting object 22218 info ...
# Collecting object 22217 info ...
# Collecting object 42864 info ...
# Collecting object 42863 info ...
# Collecting object 24024 info ...
# Collecting object 40652 info ...
# Collecting object 40650 info ...
# Collecting object 40653 info ...
# Collecting object 40651 info ...
# Collecting object 30392 info ...
# Collecting object 30393 info ...
# Collecting object 30390 info ...
# Collecting object 30391 info ...
# Collecting object 7910 info ...
# Collecting object 21778 info ...
# Collecting object 44068 info ...
# Collecting object 43079 info ...
# Collecting object 43078 info ...
# Collecting object 21323 info ...
# Collecting object 41310 info ...
# Collecting object 41309 info ...
# Collecting object 3796 info ...
# Collecting object 11915 info ...
# Collecting object 25821 info ...
# Collecting object 30693 info ...
# Collecting object 28962 info ...
# Collecting object 27510 info ...
# Collecting object 5516 info ...
# Collecting object 5525 info ...
# Collecting object 27498 info ...
# Collecting object 21658 info ...
# Collecting object 27508 info ...
# Collecting object 27523 info ...
# Collecting object 27526 info ...
# Collecting object 27506 info ...
# Collecting object 27509 info ...
# Collecting object 27515 info ...
# Collecting object 20099 info ...
# Collecting object 29667 info ...
# Collecting object 27507 info ...
# Collecting object 27503 info ...
# Collecting object 27505 info ...
# Collecting object 27522 info ...
# Collecting object 5527 info ...
# Collecting object 27517 info ...
# Collecting object 29029 info ...
# Collecting object 27501 info ...
# Collecting object 21659 info ...
# Collecting object 27499 info ...
# Collecting object 27527 info ...
# Collecting object 20100 info ...
# Collecting object 29032 info ...
# Collecting object 27521 info ...
# Collecting object 27518 info ...
# Collecting object 27513 info ...
# Collecting object 27525 info ...
# Collecting object 27524 info ...
# Collecting object 29030 info ...
# Collecting object 27516 info ...
# Collecting object 27502 info ...
# Collecting object 29028 info ...
# Collecting object 27512 info ...
# Collecting object 27520 info ...
# Collecting object 27519 info ...
# Collecting object 29031 info ...
# Collecting object 27514 info ...
# Collecting object 27504 info ...
# Collecting object 21657 info ...
# Collecting object 27500 info ...
# Collecting object 27511 info ...
# Collecting object 35086 info ...
# Collecting object 35087 info ...
# Collecting object 7822 info ...
# Collecting object 29826 info ...
# Collecting object 29827 info ...
# Collecting object 29825 info ...
# Collecting object 29822 info ...
# Collecting object 43207 info ...
# Collecting object 34040 info ...
# Collecting object 12642 info ...
# Collecting object 12635 info ...
# Collecting object 12643 info ...
# Collecting object 12633 info ...
# Collecting object 31530 info ...
# Collecting object 31422 info ...
# Collecting object 31415 info ...
# Collecting object 21592 info ...
# Collecting object 5141 info ...
# Collecting object 13511 info ...
# Collecting object 13604 info ...
# Collecting object 23382 info ...
# Collecting object 40251 info ...
# Collecting object 37313 info ...
# Collecting object 37314 info ...
# Collecting object 37312 info ...
# Collecting object 39100 info ...
# Collecting object 39099 info ...
# Collecting object 39101 info ...
# Collecting object 39102 info ...
# Collecting object 28070 info ...
# Collecting object 28072 info ...
# Collecting object 28074 info ...
# Collecting object 28071 info ...
# Collecting object 28073 info ...
# Collecting object 44447 info ...
# Collecting object 28000 info ...
# Collecting object 44023 info ...
# Collecting object 37797 info ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(table) # создаем датафрейм из таблицы
df.set_index('id', inplace=True)
df
# Out:
#        region                                            address  \
# id
# 25002      50                              село Озерецкое, д. 30
# 13399      72                    г Тюмень, ул Профсоюзная, д. 56
# 13398      72                    г Тюмень, ул Профсоюзная, д. 56
# 13383      72                                           г Тюмень
# 13397      72                    г Тюмень, ул Профсоюзная, д. 56
# ...       ...                                                ...
# 28073      50  г Котельники, район мкр.Ковровый, д.1-5, 24-29...
# 44447      76  г Ярославль, Фрунзенский район, территория в р...
# 28000      62                  г Рязань, переулок Парковый, д. 1
# 44023      76                            г Ярославль, строение 4
# 37797      59             г Пермь, улица Уинская, д. 2, литера Б
#
#                                                     name  floors  flats  \
# id
# 25002  квартал застройки № 2.7 (строительный номер 10...       5     98
# 13399                                               None       1      0
# 13398                                               None       7     43
# 13383                                               None       4     68
# 13397                                               None       6     65
# ...                                                  ...     ...    ...
# 28073                    Жилой комплекс"Котельники парк"      26    312
# 44447                                               None       6    127
# 28000                           Жилой комплекс "Невский"      20    422
# 44023                                               None      10     35
# 37797                    Лофт на Уинской "Хорошее время"       2    110
#
#        parking  ready_date        material    class  \
# id
# 25002      0.0  2021-12-31          Кирпич  Комфорт
# 13399    125.0  2024-12-31          Другое  Элитный
# 13398      0.0  2024-12-31          Другое  Элитный
# 13383     29.0  2022-06-30          Другое  Элитный
# 13397      0.0  2024-12-31          Другое  Элитный
# ...        ...         ...             ...      ...
# 28073      0.0  2024-06-30          Другое  Типовой
# 44447      0.0  2022-12-31          Кирпич  Типовой
# 28000      0.0  2021-12-31  Монолит-кирпич  Комфорт
# 44023      0.0  2021-12-31          Кирпич  Типовой
# 37797     20.0  2023-03-31  Монолит-кирпич  Комфорт
#
#                                                      url
# id
# 25002  https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D...
# 13399  https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D...
# 13398  https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D...
# 13383  https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D...
# 13397  https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D...
# ...                                                  ...
# 28073  https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D...
# 44447  https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D...
# 28000  https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D...
# 44023  https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D...
# 37797  https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D...
#
# [10202 rows x 10 columns]

# %% [markdown]
# Сохраняем в excel

# %%
df.to_excel("новостройки.xls")

# %% [markdown]
# Сохраняем в pickle

# %%
df.to_pickle("новостройки.pkl")

# %% [markdown]
# Сохраняем в БД

# %%
import sqlite3

conn = sqlite3.connect('buildings')

df.to_sql('new_buildings', conn, if_exists='replace')

conn.commit()
conn.close()

# %% [markdown]
# ## Cкачиваем фотографии всех строящихся объектов с сайта "наш.дом.рф"

# %%
from bs4 import BeautifulSoup
import json
import os.path

# %%
for id in objects_ids_total:
    print(f'Collecting images for object {id} ...')
    # !mkdir -p  {id}
    url = f'https://наш.дом.рф/сервисы/каталог-новостроек/объект/{id}'
    res  = requests.get(url).text 
    soup = BeautifulSoup(res, 'html5lib')

    data = json.loads(soup.find('script', type='application/json').text)

    # еще один способ получения информации об объекте
    # data['props']['initialState']['kn']['objectCard']['mainInfo']['data']

    objects_list = data['props']['initialState']['kn']['objectCard']['constructionProgress']['shortInfo']

    img_counter = 1 # если будут повторяющиеся имена у изображений, то сохранять новое изображение со счетчиком
    
    for obj in objects_list:
        image = requests.get(obj['src'])
        filename = obj['filename']
        path = './' + str(id) + '/'

        if os.path.isfile(path + filename):
            filename = filename[:-4] + '(' + str(img_counter) + ').jpg'
            img_counter += 1
        else:
            img_counter = 1
            
        print(f'   Saving {filename}')
        
        file = open(path + filename, 'wb')
        file.write(image.content)
        file.close()

    break # для проверки загрузки изображений одного объекта. Можно удалить и скачаются фотографии всех объектов
# Out:
# Collecting images for object 25002 ...
#    Saving obj25002_photo2018-10.jpg
#    Saving obj25002_photo2018-11.jpg
#    Saving obj25002_photo2018-11(1).jpg
#    Saving obj25002_photo2019-02.jpg
#    Saving obj25002_photo2019-02(1).jpg
#    Saving obj25002_photo2019-02(2).jpg
#    Saving obj25002_photo2019-03.jpg
#    Saving obj25002_photo2019-03(1).jpg
#    Saving obj25002_photo2019-03(2).jpg
#    Saving obj25002_photo2019-03(3).jpg
#    Saving obj25002_photo2019-03(4).jpg
#    Saving obj25002_photo2019-04.jpg
#    Saving obj25002_photo2019-04(1).jpg
#    Saving obj25002_photo2019-04(2).jpg
#    Saving obj25002_photo2019-05.jpg
#    Saving obj25002_photo2019-05(1).jpg
#    Saving obj25002_photo2019-06.jpg
#    Saving obj25002_photo2019-06(1).jpg
#    Saving obj25002_photo2019-06(2).jpg
#    Saving obj25002_photo2019-07.jpg
#    Saving obj25002_photo2019-07(1).jpg
#    Saving obj25002_photo2019-07(2).jpg
#    Saving obj25002_photo2019-07(3).jpg
#    Saving obj25002_photo2019-07(4).jpg
#    Saving obj25002_photo2019-07(5).jpg
#    Saving obj25002_photo2019-07(6).jpg
#    Saving obj25002_photo2019-09.jpg
#    Saving obj25002_photo2019-09(1).jpg
#    Saving obj25002_photo2019-09(2).jpg
#    Saving obj25002_photo2019-09(3).jpg
#    Saving obj25002_photo2019-08.jpg
#    Saving obj25002_photo2019-08(1).jpg
#    Saving obj25002_photo2019-08(2).jpg
#    Saving obj25002_photo2019-08(3).jpg
#    Saving obj25002_photo2019-10.jpg
#    Saving obj25002_photo2019-10(1).jpg
#    Saving obj25002_photo2019-10(2).jpg
#    Saving obj25002_photo2019-11.jpg
#    Saving obj25002_photo2019-11(1).jpg
#    Saving obj25002_photo2019-12.jpg
#    Saving obj25002_photo2019-12(1).jpg
#    Saving obj25002_photo2019-12(2).jpg
#    Saving obj25002_photo2019-12(3).jpg
#    Saving obj25002_photo2020-01.jpg
#    Saving obj25002_photo2020-01(1).jpg
#    Saving obj25002_photo2020-01(2).jpg
#    Saving obj25002_photo2020-01(3).jpg
#    Saving obj25002_photo2020-02.jpg
#    Saving obj25002_photo2020-02(1).jpg
#    Saving obj25002_photo2020-02(2).jpg
#    Saving obj25002_photo2020-03.jpg
#    Saving obj25002_photo2020-03(1).jpg
#    Saving obj25002_photo2020-03(2).jpg
#    Saving obj25002_photo2020-03(3).jpg
#    Saving obj25002_photo2020-04.jpg
#    Saving obj25002_photo2020-04(1).jpg
#    Saving obj25002_photo2020-05.jpg
#    Saving obj25002_photo2020-05(1).jpg
#    Saving obj25002_photo2020-06.jpg
#    Saving obj25002_photo2020-06(1).jpg
#    Saving obj25002_photo2020-07.jpg
#    Saving obj25002_photo2020-07(1).jpg
#    Saving obj25002_photo2020-08.jpg
#    Saving obj25002_photo2020-08(1).jpg
#    Saving obj25002_photo2020-09.jpg
#    Saving obj25002_photo2020-09(1).jpg
#    Saving obj25002_photo2020-10.jpg
#    Saving obj25002_photo2020-10(1).jpg
#    Saving obj25002_photo2020-11.jpg
#    Saving obj25002_photo2020-11(1).jpg
#    Saving obj25002_photo2020-12.jpg
#    Saving obj25002_photo2020-12(1).jpg
#    Saving obj25002_photo2021-01.jpg
#    Saving obj25002_photo2021-01(1).jpg
#    Saving obj25002_photo2021-02.jpg
#    Saving obj25002_photo2021-02(1).jpg
#    Saving obj25002_photo2021-03.jpg
#    Saving obj25002_photo2021-03(1).jpg
#    Saving obj25002_photo2021-04.jpg
#    Saving obj25002_photo2021-04(1).jpg
#    Saving obj25002_photo2021-04(2).jpg
#    Saving obj25002_photo2021-04(3).jpg
#    Saving obj25002_photo2021-04(4).jpg
#    Saving obj25002_photo2021-04(5).jpg
#    Saving obj25002_photo2021-04(6).jpg
#    Saving obj25002_photo2021-04(7).jpg
#    Saving obj25002_photo2021-04(8).jpg
#    Saving obj25002_photo2021-04(9).jpg
#    Saving obj25002_photo2021-04(10).jpg
#    Saving obj25002_photo2021-04(11).jpg
#    Saving obj25002_photo2021-04(12).jpg
#    Saving obj25002_photo2021-05.jpg
#    Saving obj25002_photo2021-05(1).jpg
#    Saving obj25002_photo2021-05(2).jpg
#    Saving obj25002_photo2021-06.jpg
#    Saving obj25002_photo2021-06(1).jpg
#    Saving obj25002_photo2021-06(2).jpg
#    Saving obj25002_photo2021-07.jpg
#    Saving obj25002_photo2021-07(1).jpg
#    Saving obj25002_photo2021-08.jpg
#    Saving obj25002_photo2021-09.jpg
#    Saving obj25002_photo2021-09(1).jpg
#    Saving obj25002_photo2021-10.jpg
#    Saving obj25002_photo2021-10(1).jpg
#    Saving obj25002_photo2021-10(2).jpg
#    Saving obj25002_photo2021-11.jpg
#    Saving obj25002_photo2021-12.jpg
